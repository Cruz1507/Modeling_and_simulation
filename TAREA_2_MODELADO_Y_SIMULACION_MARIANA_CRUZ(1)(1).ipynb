# %% [markdown]
# ## MARIANA CRUZ

# %% [markdown]
# Los ejercicios resueltos a mano ya fueron debidamente entregados en la sección del classroom

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.integrate import solve_ivp

# %% [markdown]
# ## 3.1 Bifurcación de punto de silla
#
# *   Para los siguientes ejercicos, grafique todos los posibles campos vectoriales cualitativamente diferentes cuando r varía.
# *   Demuestre que se produce una bifurcación de punto de silla en un valor crítico de r.
#
# *   Grafique el diagrama de bifurcación de puntos fijos x vs r
#
#
# ### 3.1.1
# \begin{equation}
# \dot{x} =1+rx+{x}^{2}
# \end{equation}

# %%
r=[-2, 0, 2]
x=np.linspace(-3,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=1+r[i]*Y+Y**2 
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=2
x_dot=1+r*x+x**2
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=1+r*x+x**2
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [-1]

# %%
def fun (t,x,r,b):
  return 1+r*x+x**2

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()

# %% [markdown]
# ### 3.1.2
# \begin{equation}
# \dot{x} =r-cosh(x)
# \end{equation}

# %%
r=[0, 1, 2]
x=np.linspace(-3,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]-np.cosh(Y) 
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=1
x_dot=r-np.cosh(x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r-sp.cosh(x)
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return r-np.cosh(x)

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([0, 5, -2.5, 2.5])
plt.grid()
# Out:
# <ipython-input-7-4fc5bf123bd8>:2: RuntimeWarning: overflow encountered in cosh
#   return r-np.cosh(x)

# %% [markdown]
# ### 3.1.3
# \begin{equation}
# \dot{x} =r+x-ln(1+x)
# \end{equation}

# %%
r=[-1, 0, 1]
x=np.linspace(-2,4,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]+Y-np.log(1+Y)
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()
# Out:
# <ipython-input-8-ed445dba53e9>:6: RuntimeWarning: invalid value encountered in log
#   v=r[i]+Y-np.log(1+Y)

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r+x-np.log(1+x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r+x-sp.log(1+x)
roots=np.abs(sp.solve(x_dot1))
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# <ipython-input-9-1cb039d56600>:3: RuntimeWarning: invalid value encountered in log
#   x_dot=r+x-np.log(1+x)
# [0 0]

# %%
def fun (t,x,r,b):
  return r+x-np.log(1+x)

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-1,5,0.2):
  for x0 in np.arange(-1,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-1,5,0.2):
  for x0 in np.arange(-1,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2, 5, -1.2, 2.5])
plt.grid()
# Out:
# <ipython-input-10-5b7dd785b6bd>:2: RuntimeWarning: divide by zero encountered in log
#   return r+x-np.log(1+x)
# C:\Users\mari-\anaconda3\lib\site-packages\scipy\integrate\_ivp\common.py:110: RuntimeWarning: invalid value encountered in multiply
#   y1 = y0 + h0 * direction * f0
# <ipython-input-10-5b7dd785b6bd>:2: RuntimeWarning: invalid value encountered in subtract
#   return r+x-np.log(1+x)
# <ipython-input-10-5b7dd785b6bd>:2: RuntimeWarning: invalid value encountered in log
#   return r+x-np.log(1+x)

# %% [markdown]
# ### 3.1.4
# \begin{equation}
# \dot{x} =r+\frac{1}{2}x-\frac{x}{1+x}
# \end{equation}

# %%
r=[-1/2, 0, 1/2]
x=np.linspace(-3,5,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]+(1/2)*Y-(Y)/(1+Y) 
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r+(1/2)*x-(x/(1+x))
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r+(1/2)*x-(x/(1+x))
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0.0, 1.00000000000000]

# %%
def fun (t,x,r,b):
  return r+(1/2)*x-(x/(1+x)) 

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-1,1,0.2):
  for x0 in np.arange(-1,1,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-1,1,0.2):
  for x0 in np.arange(-1,1,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-1, 1, -2.5, 2.5])
plt.grid()
# Out:
# <ipython-input-13-67e441a8469a>:2: RuntimeWarning: divide by zero encountered in true_divide
#   return r+(1/2)*x-(x/(1+x))
# C:\Users\mari-\anaconda3\lib\site-packages\scipy\integrate\_ivp\common.py:110: RuntimeWarning: invalid value encountered in multiply
#   y1 = y0 + h0 * direction * f0
# <ipython-input-13-67e441a8469a>:2: RuntimeWarning: invalid value encountered in true_divide
#   return r+(1/2)*x-(x/(1+x))

# %% [markdown]
# ## 3.2 Bifurcación transcritica
# ### 3.2.1
# \begin{equation}
# \dot{x} =rx+x^2
# \end{equation}

# %%
r=[-2, 0, 2]
x=np.linspace(-3,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]*Y+Y**2 
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r*x+x**2
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r*x+x**2
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return r*x+x**2

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,2.5,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,2.5,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 2.5, -2.5, 2.5])
plt.grid()

# %% [markdown]
# ### 3.2.2
# \begin{equation}
# \dot{x} =rx-ln(1+x)
# \end{equation}

# %%
r=[-2, 0, 2]
x=np.linspace(-1,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]*Y-np.log(1+Y)
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()
# Out:
# <ipython-input-17-1cdf4c5ff9ac>:6: RuntimeWarning: divide by zero encountered in log
#   v=r[i]*Y-np.log(1+Y)

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r*x-np.log(1+x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r*x-sp.log(1+x)
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# <ipython-input-18-fcaafa6414a3>:3: RuntimeWarning: invalid value encountered in log
#   x_dot=r*x-np.log(1+x)
# [0]

# %%
def fun (t,x,r,b):
  return r*x-np.log(1+x) 

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-1,2.5,0.2):
  for x0 in np.arange(-1,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-1,2.5,0.2):
  for x0 in np.arange(-1,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-1, 2.5, -2.5, 2.5])
plt.grid()
# Out:
# <ipython-input-19-dcc20c8bea7b>:2: RuntimeWarning: divide by zero encountered in log
#   return r*x-np.log(1+x)
# C:\Users\mari-\anaconda3\lib\site-packages\scipy\integrate\_ivp\common.py:110: RuntimeWarning: invalid value encountered in multiply
#   y1 = y0 + h0 * direction * f0
# <ipython-input-19-dcc20c8bea7b>:2: RuntimeWarning: invalid value encountered in subtract
#   return r*x-np.log(1+x)
# <ipython-input-19-dcc20c8bea7b>:2: RuntimeWarning: invalid value encountered in log
#   return r*x-np.log(1+x)

# %% [markdown]
# ### 3.2.3
# \begin{equation}
# \dot{x} =x-rx(1-x)
# \end{equation}

# %%
r=[-1, 0, 1]
x=np.linspace(-3,3,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=Y-r[i]*Y*(1-Y)
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=x-r*x*(1-x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=x-r*x*(1-x)
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return x-r*x*(1-x) 

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 3, -2.5, 2.5])
plt.grid()

# %% [markdown]
# ## 3.4 Bifurcación de la horquilla
# ### 3.4.1
# \begin{equation}
# \dot{x} =rx+4x^3
# \end{equation}

# %%
r=[-4, 0, 4]
x=np.linspace(-1,1,15)
y=x
X,Y=np.meshgrid(x,y)
for i in range(0,3):
  v=r[i]*Y+4*Y**3
  u=np.ones(v.shape)
  plt.figure(figsize=(7,6))
  plt.title(r'Campo vectorial para $r$ = %f' % r[i])
  plt.quiver(X,Y,u,v)
  plt.grid()

# %%
x=np.linspace(-10,10,100)
r=0
x_dot=r*x+4*x**3
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=r*x+4*x**3
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [0]

# %%
def fun (t,x,r,b):
  return r*x+4*x**3

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2.5,3,0.2):
  for x0 in np.arange(-2.5,2.5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2.5, 3, -2.5, 2.5])
plt.grid()

# %% [markdown]
# ### 3.4.5
# \begin{equation}
# \dot{x} =r-3x^3
# \end{equation}

# %%
# NO HAY BIFURCACIONES
def fun (t,x,r,b):
  return r-3*x**3

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-10,10,0.2):
  for x0 in np.arange(-10,10,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-10,10,0.2):
  for x0 in np.arange(-10,10,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-10, 10, -10, 10])
plt.grid()

# %% [markdown]
# ### 3.4.6
# \begin{equation}
# \dot{x} =rx-\frac{x}{1+x}
# \end{equation}

# %%
def fun (t,x,r,b):
  return r*x-(x/(1+x))

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-2,2,0.2):
  for x0 in np.arange(-2,2,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-2,2,0.2):
  for x0 in np.arange(-2,2,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-2, 2, -2, 2])
plt.grid()

# %% [markdown]
# ### 3.4.7
# \begin{equation}
# \dot{x} =5-r{e}^{{-x}^{2}}
# \end{equation}

# %%
def fun (t,x,r,b):
  return 5-r*np.exp(-x**2)

ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(2,10,0.2):
  for x0 in np.arange(-6,6,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(2,10,0.2):
  for x0 in np.arange(-6,6,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,2))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([2, 10, -6, 6])
plt.grid()
